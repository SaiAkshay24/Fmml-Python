# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiAkshay24/Python/blob/main/Day_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-c43e3a07-c399-4843-b0e2-efe17a3c76ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c43e3a07-c399-4843-b0e2-efe17a3c76ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
samples = np.linspace(1,7,200)
plt.plot(np.sin(samples))
plt.plot(np.cos(samples))
plt.savefig('sincos.png')
raw_image = cv.imread('chinnu.jpg',1)
vertically_stacked_image = np.vstack((raw_image,raw_image))
horizantally_stacked_image = np.hstack((vertically_stacked_image,vertically_stacked_image))
plt.imshow(vertically_stacked_image);
cv.imwrite('vertically_stacked_image.png',vertically_stacked_image)
plt.imshow(horizantally_stacked_image);
cv.imwrite('horizantally_stacked_image.png',horizantally_stacked_image)
# Out:
# True
